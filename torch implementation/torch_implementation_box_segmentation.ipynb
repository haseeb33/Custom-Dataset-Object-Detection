# %%
# Implementation in Google Colab

# !pip install cython
# Install pycocotools, the version by default in Colab
# has a bug fixed in https://github.com/cocodataset/cocoapi/pull/354
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (0.29.21)
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-85ecxa2r
#   Running command git clone -q https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-85ecxa2r
# Requirement already satisfied, skipping upgrade: setuptools>=18.0 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (49.1.0)
# Requirement already satisfied, skipping upgrade: cython>=0.27.3 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (0.29.21)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from pycocotools==2.0) (3.2.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.18.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from cycler>=0.10->matplotlib>=2.1.0->pycocotools==2.0) (1.15.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp36-cp36m-linux_x86_64.whl size=266458 sha256=9dfac25e8b86cee1be2cf58146ae773cf50f753622eed2f3057fe75dbe11540c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-idqhw00j/wheels/90/51/41/646daf401c3bc408ff10de34ec76587a9b3ebfac8d21ca5c3a
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Found existing installation: pycocotools 2.0
#     Uninstalling pycocotools-2.0:
#       Successfully uninstalled pycocotools-2.0
# Successfully installed pycocotools-2.0
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.6.0+cu101 in /usr/local/lib/python3.6/dist-packages (1.6.0+cu101)
# Requirement already satisfied: torchvision==0.7.0+cu101 in /usr/local/lib/python3.6/dist-packages (0.7.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0+cu101) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0+cu101) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.7.0+cu101) (7.0.0)

# %%
import os
import json
import numpy as np
import torch
import torch.utils.data
from PIL import Image
import skimage.io
import cv2
import skimage.draw
from matplotlib import pyplot as plt

class Dataset(torch.utils.data.Dataset):
    def __init__(self, root, json_file, transforms=None):
        self.root = root
        self.transforms = transforms
        classes_dict = {"class":1}
        self.polygons = []
        self.imgs = []
        dataset_dir = root
        # annotations create using makesense.ai online annotation tool in VGG Json format
        annotations = json.load(open(os.path.join(dataset_dir, json_file)))
        annotations = list(annotations.values())  # don't need the dict keys

        annotations = [a for a in annotations if a['regions']]
        for a in annotations:
            polygon = [r['shape_attributes'] for r in a['regions'].values()]
            self.polygons.append(polygon)
            self.imgs.append(os.path.join(dataset_dir, a['filename']))

    def __getitem__(self, idx):
        # load images and masks
        img_path = self.imgs[idx]
        masks_p = self.polygons[idx] # json polygon. work on this one
        img = Image.open(img_path).convert("RGB")

        image = skimage.io.imread(img_path)
        height, width = image.shape[:2]

        masks = np.zeros([len(masks_p), height, width],
                        dtype=np.bool)

        for i, p in enumerate(masks_p):
            # Get indexes of pixels inside the polygon and set them to True
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            masks[i, rr, cc] = True

        # get bounding box coordinates for each mask
        num_objs = len(masks_p)
        boxes = []
        for i in range(num_objs):
            pos = np.where(masks[i])
            xmin = np.min(pos[1])
            xmax = np.max(pos[1])
            ymin = np.min(pos[0])
            ymax = np.max(pos[0])
            boxes.append([xmin, ymin, xmax, ymax])

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        # there is only one class so creating labels like this
        labels = torch.ones((num_objs,), dtype=torch.int64)
        masks = torch.as_tensor(masks, dtype=torch.uint8)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        target = {}
        target["classes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd
      
        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
# %%shell
# # Only ONCE
# # Download TorchVision repo to use some files from
# # references/detection
# #git clone https://github.com/pytorch/vision.git
# cd vision
# #git checkout v0.3.0
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../

# %%
from engine import train_one_epoch, evaluate
import utils
import transforms as T


def get_transform(train):
    transforms = []
    # converts the image, a PIL image, into a PyTorch Tensor
    transforms.append(T.ToTensor())
    if train:
        # during training, randomly flip the training images
        # and ground-truth for data augmentation
        transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]))
    return T.Compose(transforms)

# %%
dataset_train = Dataset("Main/train", "train_label.json", get_transform(train=True))
dataset_val = Dataset("Main/val", "val_label.json", get_transform(train=False))

# %%
trainable_backbone_layers=2

import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
   
def get_instance_segmentation_model(num_classes):
    # load an instance segmentation model pre-trained on COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True, trainable_backbone_layers=trainable_backbone_layers)

    # get the number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # now get the number of input features for the mask classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256 # change this and see the results
    # and replace the mask predictor with a new one
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                       hidden_layer,
                                                       num_classes)

    return model

# %%
# define training and validation data loaders
data_loader_train = torch.utils.data.DataLoader(
    dataset_train, batch_size=2, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_val = torch.utils.data.DataLoader(
    dataset_val, batch_size=1, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
# our dataset has two classes only - background and class
num_classes = 2

# get the model using our helper function
model = get_instance_segmentation_model(num_classes)
# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 10 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=10,
                                               gamma=0.1)
# Out:
# cuda

# %%
# let's train it for 15 epochs
num_epochs = 20

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader_train, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_val, device=device)

torch.save(model.state_dict(), "{}_layer_trained_model_{}epoch.bin".format(trainable_backbone_layers, num_epochs))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# Epoch: [0]  [ 0/45]  eta: 0:02:02  lr: 0.000119  loss: 4.8921 (4.8921)  loss_classifier: 0.6159 (0.6159)  loss_box_reg: 0.4502 (0.4502)  loss_mask: 2.6733 (2.6733)  loss_objectness: 1.0513 (1.0513)  loss_rpn_box_reg: 0.1013 (0.1013)  time: 2.7272  data: 2.0974  max mem: 3174
# Epoch: [0]  [10/45]  eta: 0:00:52  lr: 0.001254  loss: 3.3877 (3.5689)  loss_classifier: 0.5542 (0.5346)  loss_box_reg: 0.5319 (0.6036)  loss_mask: 1.5652 (1.6619)  loss_objectness: 0.6827 (0.6729)  loss_rpn_box_reg: 0.0992 (0.0959)  time: 1.4899  data: 0.8223  max mem: 3234
# Epoch: [0]  [20/45]  eta: 0:00:28  lr: 0.002389  loss: 2.6035 (2.8270)  loss_classifier: 0.4396 (0.4804)  loss_box_reg: 0.7462 (0.7110)  loss_mask: 0.7996 (1.1116)  loss_objectness: 0.1591 (0.4481)  loss_rpn_box_reg: 0.0695 (0.0759)  time: 1.0791  data: 0.4046  max mem: 3250
# Epoch: [0]  [30/45]  eta: 0:00:16  lr: 0.003524  loss: 1.6844 (2.3856)  loss_classifier: 0.3777 (0.4285)  loss_box_reg: 0.7462 (0.7187)  loss_mask: 0.3298 (0.8468)  loss_objectness: 0.1200 (0.3257)  loss_rpn_box_reg: 0.0398 (0.0658)  time: 0.8375  data: 0.1625  max mem: 3353
# Epoch: [0]  [40/45]  eta: 0:00:05  lr: 0.004659  loss: 1.1641 (2.0279)  loss_classifier: 0.2254 (0.3718)  loss_box_reg: 0.6195 (0.6488)  loss_mask: 0.2037 (0.6974)  loss_objectness: 0.0407 (0.2536)  loss_rpn_box_reg: 0.0246 (0.0563)  time: 0.8485  data: 0.1799  max mem: 3363
# Epoch: [0]  [44/45]  eta: 0:00:00  lr: 0.005000  loss: 0.9761 (1.9126)  loss_classifier: 0.2179 (0.3550)  loss_box_reg: 0.4541 (0.6219)  loss_mask: 0.1915 (0.6507)  loss_objectness: 0.0232 (0.2321)  loss_rpn_box_reg: 0.0239 (0.0530)  time: 0.8310  data: 0.1748  max mem: 3363
# Epoch: [0] Total time: 0:00:44 (0.9801 s / it)
# creating index...
# index created!
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Test:  [ 0/16]  eta: 0:00:16  model_time: 0.3765 (0.3765)  evaluator_time: 0.1580 (0.1580)  time: 1.0455  data: 0.5077  max mem: 3363
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1645 (0.2074)  evaluator_time: 0.0547 (0.0955)  time: 0.3455  data: 0.0366  max mem: 3363
# Test: Total time: 0:00:05 (0.3603 s / it)
# Averaged stats: model_time: 0.1645 (0.2074)  evaluator_time: 0.0547 (0.0955)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.728
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.987
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.677
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.639
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.775
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.737
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.789
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.795
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.987
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.936
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.741
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.682
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.831
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.802
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.842
# Epoch: [1]  [ 0/45]  eta: 0:01:50  lr: 0.005000  loss: 0.5622 (0.5622)  loss_classifier: 0.1263 (0.1263)  loss_box_reg: 0.2600 (0.2600)  loss_mask: 0.1656 (0.1656)  loss_objectness: 0.0053 (0.0053)  loss_rpn_box_reg: 0.0050 (0.0050)  time: 2.4655  data: 1.8625  max mem: 3363
# Epoch: [1]  [10/45]  eta: 0:00:34  lr: 0.005000  loss: 0.6617 (0.6929)  loss_classifier: 0.1429 (0.1630)  loss_box_reg: 0.3038 (0.3278)  loss_mask: 0.1369 (0.1457)  loss_objectness: 0.0159 (0.0270)  loss_rpn_box_reg: 0.0265 (0.0295)  time: 0.9716  data: 0.3000  max mem: 3363
# Epoch: [1]  [20/45]  eta: 0:00:23  lr: 0.005000  loss: 0.6617 (0.6655)  loss_classifier: 0.1429 (0.1645)  loss_box_reg: 0.3023 (0.3076)  loss_mask: 0.1334 (0.1442)  loss_objectness: 0.0133 (0.0216)  loss_rpn_box_reg: 0.0255 (0.0276)  time: 0.8599  data: 0.1693  max mem: 3363
# Epoch: [1]  [30/45]  eta: 0:00:13  lr: 0.005000  loss: 0.4814 (0.6190)  loss_classifier: 0.1129 (0.1483)  loss_box_reg: 0.2267 (0.2830)  loss_mask: 0.1267 (0.1444)  loss_objectness: 0.0149 (0.0200)  loss_rpn_box_reg: 0.0174 (0.0233)  time: 0.8278  data: 0.1237  max mem: 3363
# Epoch: [1]  [40/45]  eta: 0:00:04  lr: 0.005000  loss: 0.4957 (0.6241)  loss_classifier: 0.1129 (0.1577)  loss_box_reg: 0.1991 (0.2702)  loss_mask: 0.1196 (0.1449)  loss_objectness: 0.0151 (0.0253)  loss_rpn_box_reg: 0.0142 (0.0260)  time: 1.0435  data: 0.3665  max mem: 3363
# Epoch: [1]  [44/45]  eta: 0:00:00  lr: 0.005000  loss: 0.4511 (0.6128)  loss_classifier: 0.1129 (0.1537)  loss_box_reg: 0.1991 (0.2653)  loss_mask: 0.1158 (0.1428)  loss_objectness: 0.0169 (0.0248)  loss_rpn_box_reg: 0.0194 (0.0262)  time: 1.0658  data: 0.4047  max mem: 3363
# Epoch: [1] Total time: 0:00:44 (0.9849 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:15  model_time: 0.4175 (0.4175)  evaluator_time: 0.1636 (0.1636)  time: 0.9735  data: 0.3892  max mem: 3363
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1552 (0.2253)  evaluator_time: 0.0643 (0.1070)  time: 0.3700  data: 0.0314  max mem: 3363
# Test: Total time: 0:00:06 (0.3851 s / it)
# Averaged stats: model_time: 0.1552 (0.2253)  evaluator_time: 0.0643 (0.1070)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.799
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.958
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.772
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.835
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.840
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.876
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.992
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.949
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.816
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.896
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.727
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.868
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.916
# Epoch: [2]  [ 0/45]  eta: 0:04:26  lr: 0.005000  loss: 0.5317 (0.5317)  loss_classifier: 0.1307 (0.1307)  loss_box_reg: 0.2028 (0.2028)  loss_mask: 0.1510 (0.1510)  loss_objectness: 0.0323 (0.0323)  loss_rpn_box_reg: 0.0149 (0.0149)  time: 5.9127  data: 5.1762  max mem: 3363
# Epoch: [2]  [10/45]  eta: 0:00:56  lr: 0.005000  loss: 0.3551 (0.4382)  loss_classifier: 0.0902 (0.1152)  loss_box_reg: 0.1561 (0.1719)  loss_mask: 0.0943 (0.1114)  loss_objectness: 0.0152 (0.0180)  loss_rpn_box_reg: 0.0160 (0.0217)  time: 1.6258  data: 0.9306  max mem: 3367
# Epoch: [2]  [20/45]  eta: 0:00:32  lr: 0.005000  loss: 0.3551 (0.4234)  loss_classifier: 0.0912 (0.1105)  loss_box_reg: 0.1561 (0.1722)  loss_mask: 0.0943 (0.1081)  loss_objectness: 0.0099 (0.0136)  loss_rpn_box_reg: 0.0160 (0.0190)  time: 1.0712  data: 0.3952  max mem: 3367
# Epoch: [2]  [30/45]  eta: 0:00:17  lr: 0.005000  loss: 0.3757 (0.4181)  loss_classifier: 0.0914 (0.1091)  loss_box_reg: 0.1644 (0.1705)  loss_mask: 0.0960 (0.1065)  loss_objectness: 0.0084 (0.0132)  loss_rpn_box_reg: 0.0136 (0.0188)  time: 0.9446  data: 0.2658  max mem: 3367
# Epoch: [2]  [40/45]  eta: 0:00:05  lr: 0.005000  loss: 0.3382 (0.4112)  loss_classifier: 0.0865 (0.1083)  loss_box_reg: 0.1467 (0.1691)  loss_mask: 0.0908 (0.1038)  loss_objectness: 0.0061 (0.0128)  loss_rpn_box_reg: 0.0103 (0.0172)  time: 0.8402  data: 0.1502  max mem: 3367
# Epoch: [2]  [44/45]  eta: 0:00:01  lr: 0.005000  loss: 0.3233 (0.4070)  loss_classifier: 0.0815 (0.1066)  loss_box_reg: 0.1467 (0.1681)  loss_mask: 0.0893 (0.1034)  loss_objectness: 0.0038 (0.0122)  loss_rpn_box_reg: 0.0079 (0.0168)  time: 0.7594  data: 0.0814  max mem: 3367
# Epoch: [2] Total time: 0:00:46 (1.0428 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:13  model_time: 0.2919 (0.2919)  evaluator_time: 0.0604 (0.0604)  time: 0.8606  data: 0.4945  max mem: 3367
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1138 (0.1576)  evaluator_time: 0.0280 (0.0490)  time: 0.2549  data: 0.0419  max mem: 3367
# Test: Total time: 0:00:04 (0.2705 s / it)
# Averaged stats: model_time: 0.1138 (0.1576)  evaluator_time: 0.0280 (0.0490)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.798
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.999
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.748
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.815
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.829
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.778
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.846
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.872
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.999
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.817
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.890
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.895
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.856
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.908
# Epoch: [3]  [ 0/45]  eta: 0:02:37  lr: 0.005000  loss: 0.4120 (0.4120)  loss_classifier: 0.0974 (0.0974)  loss_box_reg: 0.2001 (0.2001)  loss_mask: 0.1018 (0.1018)  loss_objectness: 0.0024 (0.0024)  loss_rpn_box_reg: 0.0102 (0.0102)  time: 3.5057  data: 2.7648  max mem: 3367
# Epoch: [3]  [10/45]  eta: 0:00:44  lr: 0.005000  loss: 0.3440 (0.3137)  loss_classifier: 0.0756 (0.0754)  loss_box_reg: 0.1328 (0.1426)  loss_mask: 0.0871 (0.0831)  loss_objectness: 0.0037 (0.0047)  loss_rpn_box_reg: 0.0072 (0.0079)  time: 1.2826  data: 0.5674  max mem: 3367
# Epoch: [3]  [20/45]  eta: 0:00:27  lr: 0.005000  loss: 0.3250 (0.3476)  loss_classifier: 0.0766 (0.0926)  loss_box_reg: 0.1383 (0.1487)  loss_mask: 0.0871 (0.0896)  loss_objectness: 0.0044 (0.0067)  loss_rpn_box_reg: 0.0088 (0.0099)  time: 0.9857  data: 0.2770  max mem: 3367
# Epoch: [3]  [30/45]  eta: 0:00:15  lr: 0.005000  loss: 0.3250 (0.3610)  loss_classifier: 0.0850 (0.0954)  loss_box_reg: 0.1383 (0.1496)  loss_mask: 0.0927 (0.0939)  loss_objectness: 0.0046 (0.0070)  loss_rpn_box_reg: 0.0100 (0.0151)  time: 0.9333  data: 0.2392  max mem: 3367
# Epoch: [3]  [40/45]  eta: 0:00:04  lr: 0.005000  loss: 0.2717 (0.3330)  loss_classifier: 0.0631 (0.0865)  loss_box_reg: 0.1053 (0.1386)  loss_mask: 0.0794 (0.0889)  loss_objectness: 0.0039 (0.0061)  loss_rpn_box_reg: 0.0089 (0.0130)  time: 0.8129  data: 0.1471  max mem: 3367
# Epoch: [3]  [44/45]  eta: 0:00:00  lr: 0.005000  loss: 0.2576 (0.3361)  loss_classifier: 0.0631 (0.0871)  loss_box_reg: 0.1053 (0.1395)  loss_mask: 0.0771 (0.0904)  loss_objectness: 0.0038 (0.0061)  loss_rpn_box_reg: 0.0089 (0.0130)  time: 0.7807  data: 0.1412  max mem: 3367
# Epoch: [3] Total time: 0:00:42 (0.9357 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:13  model_time: 0.2815 (0.2815)  evaluator_time: 0.0610 (0.0610)  time: 0.8224  data: 0.4770  max mem: 3367
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1133 (0.1541)  evaluator_time: 0.0331 (0.0469)  time: 0.2478  data: 0.0409  max mem: 3367
# Test: Total time: 0:00:04 (0.2637 s / it)
# Averaged stats: model_time: 0.1133 (0.1541)  evaluator_time: 0.0331 (0.0469)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.840
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.788
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.854
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.084
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.685
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.866
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.873
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.892
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.953
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.805
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.914
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.721
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.913
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.878
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.927
# Epoch: [4]  [ 0/45]  eta: 0:03:28  lr: 0.005000  loss: 0.3520 (0.3520)  loss_classifier: 0.0958 (0.0958)  loss_box_reg: 0.1302 (0.1302)  loss_mask: 0.1148 (0.1148)  loss_objectness: 0.0048 (0.0048)  loss_rpn_box_reg: 0.0063 (0.0063)  time: 4.6350  data: 3.7740  max mem: 3367
# Epoch: [4]  [10/45]  eta: 0:00:42  lr: 0.005000  loss: 0.2651 (0.2991)  loss_classifier: 0.0600 (0.0788)  loss_box_reg: 0.1038 (0.1175)  loss_mask: 0.0855 (0.0891)  loss_objectness: 0.0036 (0.0056)  loss_rpn_box_reg: 0.0063 (0.0081)  time: 1.2147  data: 0.5181  max mem: 3367
# Epoch: [4]  [20/45]  eta: 0:00:24  lr: 0.005000  loss: 0.2562 (0.3016)  loss_classifier: 0.0600 (0.0747)  loss_box_reg: 0.1039 (0.1237)  loss_mask: 0.0779 (0.0915)  loss_objectness: 0.0026 (0.0040)  loss_rpn_box_reg: 0.0062 (0.0077)  time: 0.8059  data: 0.1202  max mem: 3367
# Epoch: [4]  [30/45]  eta: 0:00:14  lr: 0.005000  loss: 0.2716 (0.3189)  loss_classifier: 0.0639 (0.0795)  loss_box_reg: 0.1164 (0.1284)  loss_mask: 0.0779 (0.0950)  loss_objectness: 0.0029 (0.0051)  loss_rpn_box_reg: 0.0072 (0.0109)  time: 0.8547  data: 0.1570  max mem: 3367
# Epoch: [4]  [40/45]  eta: 0:00:04  lr: 0.005000  loss: 0.2492 (0.3010)  loss_classifier: 0.0558 (0.0734)  loss_box_reg: 0.1063 (0.1227)  loss_mask: 0.0801 (0.0906)  loss_objectness: 0.0025 (0.0045)  loss_rpn_box_reg: 0.0064 (0.0098)  time: 0.8762  data: 0.1873  max mem: 3367
# Epoch: [4]  [44/45]  eta: 0:00:00  lr: 0.005000  loss: 0.2520 (0.2973)  loss_classifier: 0.0547 (0.0720)  loss_box_reg: 0.1100 (0.1212)  loss_mask: 0.0802 (0.0897)  loss_objectness: 0.0022 (0.0044)  loss_rpn_box_reg: 0.0061 (0.0099)  time: 0.8443  data: 0.1826  max mem: 3367
# Epoch: [4] Total time: 0:00:41 (0.9114 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:11  model_time: 0.2516 (0.2516)  evaluator_time: 0.0504 (0.0504)  time: 0.7435  data: 0.4387  max mem: 3367
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1086 (0.1394)  evaluator_time: 0.0238 (0.0440)  time: 0.2354  data: 0.0472  max mem: 3367
# Test: Total time: 0:00:04 (0.2520 s / it)
# Averaged stats: model_time: 0.1086 (0.1394)  evaluator_time: 0.0238 (0.0440)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.884
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.967
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.854
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.898
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.738
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.909
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.885
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.918
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.988
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.967
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.267
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.843
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.916
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.922
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.898
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.931
# Epoch: [5]  [ 0/45]  eta: 0:01:45  lr: 0.005000  loss: 0.1812 (0.1812)  loss_classifier: 0.0313 (0.0313)  loss_box_reg: 0.0716 (0.0716)  loss_mask: 0.0710 (0.0710)  loss_objectness: 0.0019 (0.0019)  loss_rpn_box_reg: 0.0054 (0.0054)  time: 2.3553  data: 1.5326  max mem: 3367
# Epoch: [5]  [10/45]  eta: 0:00:44  lr: 0.005000  loss: 0.2397 (0.2487)  loss_classifier: 0.0537 (0.0543)  loss_box_reg: 0.1027 (0.0990)  loss_mask: 0.0759 (0.0846)  loss_objectness: 0.0024 (0.0026)  loss_rpn_box_reg: 0.0072 (0.0082)  time: 1.2815  data: 0.5572  max mem: 3367
# Epoch: [5]  [20/45]  eta: 0:00:25  lr: 0.005000  loss: 0.2397 (0.2703)  loss_classifier: 0.0544 (0.0683)  loss_box_reg: 0.1027 (0.1045)  loss_mask: 0.0794 (0.0869)  loss_objectness: 0.0022 (0.0030)  loss_rpn_box_reg: 0.0061 (0.0077)  time: 0.9612  data: 0.2756  max mem: 3367
# Epoch: [5]  [30/45]  eta: 0:00:14  lr: 0.005000  loss: 0.2689 (0.3011)  loss_classifier: 0.0656 (0.0788)  loss_box_reg: 0.1095 (0.1152)  loss_mask: 0.0850 (0.0917)  loss_objectness: 0.0028 (0.0045)  loss_rpn_box_reg: 0.0079 (0.0109)  time: 0.8026  data: 0.1100  max mem: 3399
# Epoch: [5]  [40/45]  eta: 0:00:04  lr: 0.005000  loss: 0.2886 (0.2996)  loss_classifier: 0.0723 (0.0763)  loss_box_reg: 0.1228 (0.1193)  loss_mask: 0.0810 (0.0894)  loss_objectness: 0.0039 (0.0041)  loss_rpn_box_reg: 0.0101 (0.0105)  time: 0.8675  data: 0.1578  max mem: 3399
# Epoch: [5]  [44/45]  eta: 0:00:00  lr: 0.005000  loss: 0.2858 (0.3005)  loss_classifier: 0.0665 (0.0759)  loss_box_reg: 0.1239 (0.1213)  loss_mask: 0.0760 (0.0891)  loss_objectness: 0.0028 (0.0040)  loss_rpn_box_reg: 0.0094 (0.0103)  time: 0.7755  data: 0.1019  max mem: 3399
# Epoch: [5] Total time: 0:00:41 (0.9214 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:14  model_time: 0.3103 (0.3103)  evaluator_time: 0.0448 (0.0448)  time: 0.8791  data: 0.5212  max mem: 3399
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1045 (0.1451)  evaluator_time: 0.0217 (0.0372)  time: 0.2354  data: 0.0469  max mem: 3399
# Test: Total time: 0:00:04 (0.2505 s / it)
# Averaged stats: model_time: 0.1045 (0.1451)  evaluator_time: 0.0217 (0.0372)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.973
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.813
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.882
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.895
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.902
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.999
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.961
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.826
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.924
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.736
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.925
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.880
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.940
# Epoch: [6]  [ 0/45]  eta: 0:01:50  lr: 0.005000  loss: 0.3049 (0.3049)  loss_classifier: 0.0665 (0.0665)  loss_box_reg: 0.1211 (0.1211)  loss_mask: 0.1017 (0.1017)  loss_objectness: 0.0090 (0.0090)  loss_rpn_box_reg: 0.0066 (0.0066)  time: 2.4533  data: 1.6531  max mem: 3399
# Epoch: [6]  [10/45]  eta: 0:00:43  lr: 0.005000  loss: 0.2973 (0.2836)  loss_classifier: 0.0537 (0.0656)  loss_box_reg: 0.1141 (0.1103)  loss_mask: 0.0818 (0.0910)  loss_objectness: 0.0031 (0.0054)  loss_rpn_box_reg: 0.0056 (0.0115)  time: 1.2403  data: 0.5532  max mem: 3399
# Epoch: [6]  [20/45]  eta: 0:00:24  lr: 0.005000  loss: 0.2087 (0.2504)  loss_classifier: 0.0512 (0.0586)  loss_box_reg: 0.0831 (0.0968)  loss_mask: 0.0700 (0.0823)  loss_objectness: 0.0016 (0.0041)  loss_rpn_box_reg: 0.0052 (0.0087)  time: 0.9209  data: 0.2399  max mem: 3399
# Epoch: [6]  [30/45]  eta: 0:00:14  lr: 0.005000  loss: 0.2156 (0.2548)  loss_classifier: 0.0498 (0.0602)  loss_box_reg: 0.0831 (0.0968)  loss_mask: 0.0752 (0.0846)  loss_objectness: 0.0016 (0.0042)  loss_rpn_box_reg: 0.0052 (0.0090)  time: 0.7901  data: 0.1025  max mem: 3399
# Epoch: [6]  [40/45]  eta: 0:00:04  lr: 0.005000  loss: 0.2304 (0.2497)  loss_classifier: 0.0535 (0.0600)  loss_box_reg: 0.0940 (0.0960)  loss_mask: 0.0753 (0.0819)  loss_objectness: 0.0015 (0.0037)  loss_rpn_box_reg: 0.0050 (0.0081)  time: 0.8602  data: 0.1573  max mem: 3399
# Epoch: [6]  [44/45]  eta: 0:00:00  lr: 0.005000  loss: 0.2304 (0.2535)  loss_classifier: 0.0535 (0.0628)  loss_box_reg: 0.0940 (0.0971)  loss_mask: 0.0741 (0.0813)  loss_objectness: 0.0016 (0.0040)  loss_rpn_box_reg: 0.0052 (0.0083)  time: 0.8387  data: 0.1533  max mem: 3399
# Epoch: [6] Total time: 0:00:40 (0.9083 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:12  model_time: 0.2720 (0.2720)  evaluator_time: 0.0444 (0.0444)  time: 0.8021  data: 0.4828  max mem: 3399
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1065 (0.1458)  evaluator_time: 0.0247 (0.0400)  time: 0.2345  data: 0.0437  max mem: 3399
# Test: Total time: 0:00:03 (0.2489 s / it)
# Averaged stats: model_time: 0.1065 (0.1458)  evaluator_time: 0.0247 (0.0400)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.890
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.998
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.967
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.843
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.868
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.925
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.899
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.967
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.845
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.921
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.743
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.876
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.934
# Epoch: [7]  [ 0/45]  eta: 0:01:54  lr: 0.005000  loss: 0.1736 (0.1736)  loss_classifier: 0.0431 (0.0431)  loss_box_reg: 0.0595 (0.0595)  loss_mask: 0.0642 (0.0642)  loss_objectness: 0.0034 (0.0034)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 2.5550  data: 1.8133  max mem: 3399
# Epoch: [7]  [10/45]  eta: 0:00:37  lr: 0.005000  loss: 0.1957 (0.1909)  loss_classifier: 0.0441 (0.0423)  loss_box_reg: 0.0727 (0.0734)  loss_mask: 0.0642 (0.0680)  loss_objectness: 0.0018 (0.0023)  loss_rpn_box_reg: 0.0038 (0.0048)  time: 1.0651  data: 0.4006  max mem: 3399
# Epoch: [7]  [20/45]  eta: 0:00:27  lr: 0.005000  loss: 0.2015 (0.2092)  loss_classifier: 0.0466 (0.0491)  loss_box_reg: 0.0782 (0.0787)  loss_mask: 0.0713 (0.0732)  loss_objectness: 0.0018 (0.0027)  loss_rpn_box_reg: 0.0049 (0.0054)  time: 1.0470  data: 0.3629  max mem: 3605
# Epoch: [7]  [30/45]  eta: 0:00:16  lr: 0.005000  loss: 0.2056 (0.2125)  loss_classifier: 0.0482 (0.0487)  loss_box_reg: 0.0825 (0.0799)  loss_mask: 0.0750 (0.0755)  loss_objectness: 0.0023 (0.0026)  loss_rpn_box_reg: 0.0061 (0.0057)  time: 1.0817  data: 0.3712  max mem: 3605
# Epoch: [7]  [40/45]  eta: 0:00:04  lr: 0.005000  loss: 0.2221 (0.2151)  loss_classifier: 0.0483 (0.0506)  loss_box_reg: 0.0825 (0.0811)  loss_mask: 0.0744 (0.0756)  loss_objectness: 0.0010 (0.0023)  loss_rpn_box_reg: 0.0044 (0.0054)  time: 0.8613  data: 0.1564  max mem: 3605
# Epoch: [7]  [44/45]  eta: 0:00:01  lr: 0.005000  loss: 0.2269 (0.2306)  loss_classifier: 0.0511 (0.0554)  loss_box_reg: 0.0828 (0.0865)  loss_mask: 0.0754 (0.0774)  loss_objectness: 0.0008 (0.0044)  loss_rpn_box_reg: 0.0036 (0.0070)  time: 0.9386  data: 0.2685  max mem: 3605
# Epoch: [7] Total time: 0:00:45 (1.0139 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:10  model_time: 0.2624 (0.2624)  evaluator_time: 0.0360 (0.0360)  time: 0.6858  data: 0.3839  max mem: 3605
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1043 (0.1444)  evaluator_time: 0.0182 (0.0351)  time: 0.2326  data: 0.0471  max mem: 3605
# Test: Total time: 0:00:03 (0.2477 s / it)
# Averaged stats: model_time: 0.1043 (0.1444)  evaluator_time: 0.0182 (0.0351)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.874
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.988
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.977
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.817
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.899
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.903
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.866
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.922
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.908
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.988
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.965
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.837
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.938
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.747
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.930
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.885
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.951
# Epoch: [8]  [ 0/45]  eta: 0:04:25  lr: 0.005000  loss: 0.2551 (0.2551)  loss_classifier: 0.0588 (0.0588)  loss_box_reg: 0.1081 (0.1081)  loss_mask: 0.0736 (0.0736)  loss_objectness: 0.0036 (0.0036)  loss_rpn_box_reg: 0.0111 (0.0111)  time: 5.9104  data: 4.9988  max mem: 3605
# Epoch: [8]  [10/45]  eta: 0:00:45  lr: 0.005000  loss: 0.2455 (0.2377)  loss_classifier: 0.0588 (0.0582)  loss_box_reg: 0.0888 (0.0931)  loss_mask: 0.0716 (0.0740)  loss_objectness: 0.0055 (0.0063)  loss_rpn_box_reg: 0.0059 (0.0061)  time: 1.2992  data: 0.5757  max mem: 3605
# Epoch: [8]  [20/45]  eta: 0:00:31  lr: 0.005000  loss: 0.2289 (0.2324)  loss_classifier: 0.0542 (0.0566)  loss_box_reg: 0.0846 (0.0898)  loss_mask: 0.0710 (0.0731)  loss_objectness: 0.0034 (0.0058)  loss_rpn_box_reg: 0.0042 (0.0072)  time: 1.0219  data: 0.3183  max mem: 3605
# Epoch: [8]  [30/45]  eta: 0:00:16  lr: 0.005000  loss: 0.2026 (0.2243)  loss_classifier: 0.0432 (0.0537)  loss_box_reg: 0.0812 (0.0879)  loss_mask: 0.0684 (0.0719)  loss_objectness: 0.0015 (0.0044)  loss_rpn_box_reg: 0.0041 (0.0064)  time: 0.9550  data: 0.2617  max mem: 3605
# Epoch: [8]  [40/45]  eta: 0:00:05  lr: 0.005000  loss: 0.2031 (0.2294)  loss_classifier: 0.0445 (0.0544)  loss_box_reg: 0.0812 (0.0887)  loss_mask: 0.0722 (0.0747)  loss_objectness: 0.0012 (0.0041)  loss_rpn_box_reg: 0.0043 (0.0074)  time: 0.8039  data: 0.1238  max mem: 3605
# Epoch: [8]  [44/45]  eta: 0:00:00  lr: 0.005000  loss: 0.2119 (0.2292)  loss_classifier: 0.0487 (0.0543)  loss_box_reg: 0.0839 (0.0882)  loss_mask: 0.0732 (0.0751)  loss_objectness: 0.0015 (0.0042)  loss_rpn_box_reg: 0.0057 (0.0074)  time: 0.7738  data: 0.1213  max mem: 3605
# Epoch: [8] Total time: 0:00:44 (0.9989 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:13  model_time: 0.2851 (0.2851)  evaluator_time: 0.0443 (0.0443)  time: 0.8144  data: 0.4821  max mem: 3605
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1069 (0.1395)  evaluator_time: 0.0188 (0.0350)  time: 0.2287  data: 0.0481  max mem: 3605
# Test: Total time: 0:00:03 (0.2433 s / it)
# Averaged stats: model_time: 0.1069 (0.1395)  evaluator_time: 0.0188 (0.0350)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.866
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.958
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.797
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.891
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.896
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.824
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.919
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.958
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.826
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.927
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.743
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.919
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.859
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.940
# Epoch: [9]  [ 0/45]  eta: 0:02:05  lr: 0.005000  loss: 0.2190 (0.2190)  loss_classifier: 0.0491 (0.0491)  loss_box_reg: 0.0830 (0.0830)  loss_mask: 0.0834 (0.0834)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0027 (0.0027)  time: 2.7982  data: 1.9558  max mem: 3605
# Epoch: [9]  [10/45]  eta: 0:00:40  lr: 0.005000  loss: 0.2062 (0.2077)  loss_classifier: 0.0491 (0.0483)  loss_box_reg: 0.0735 (0.0775)  loss_mask: 0.0743 (0.0756)  loss_objectness: 0.0013 (0.0020)  loss_rpn_box_reg: 0.0031 (0.0043)  time: 1.1697  data: 0.4562  max mem: 3605
# Epoch: [9]  [20/45]  eta: 0:00:32  lr: 0.005000  loss: 0.1860 (0.2074)  loss_classifier: 0.0474 (0.0491)  loss_box_reg: 0.0669 (0.0745)  loss_mask: 0.0705 (0.0753)  loss_objectness: 0.0015 (0.0027)  loss_rpn_box_reg: 0.0034 (0.0058)  time: 1.2085  data: 0.5092  max mem: 3605
# Epoch: [9]  [30/45]  eta: 0:00:18  lr: 0.005000  loss: 0.1729 (0.2063)  loss_classifier: 0.0381 (0.0493)  loss_box_reg: 0.0580 (0.0720)  loss_mask: 0.0696 (0.0757)  loss_objectness: 0.0015 (0.0029)  loss_rpn_box_reg: 0.0041 (0.0064)  time: 1.2626  data: 0.5711  max mem: 3605
# Epoch: [9]  [40/45]  eta: 0:00:05  lr: 0.005000  loss: 0.1693 (0.1976)  loss_classifier: 0.0359 (0.0474)  loss_box_reg: 0.0540 (0.0689)  loss_mask: 0.0639 (0.0722)  loss_objectness: 0.0014 (0.0027)  loss_rpn_box_reg: 0.0046 (0.0063)  time: 0.9953  data: 0.2742  max mem: 3605
# Epoch: [9]  [44/45]  eta: 0:00:01  lr: 0.005000  loss: 0.1697 (0.1975)  loss_classifier: 0.0359 (0.0470)  loss_box_reg: 0.0613 (0.0688)  loss_mask: 0.0639 (0.0731)  loss_objectness: 0.0009 (0.0025)  loss_rpn_box_reg: 0.0040 (0.0061)  time: 1.0144  data: 0.3063  max mem: 3605
# Epoch: [9] Total time: 0:00:50 (1.1205 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:11  model_time: 0.2538 (0.2538)  evaluator_time: 0.0613 (0.0613)  time: 0.7072  data: 0.3891  max mem: 3605
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1036 (0.1427)  evaluator_time: 0.0166 (0.0348)  time: 0.2241  data: 0.0407  max mem: 3605
# Test: Total time: 0:00:03 (0.2399 s / it)
# Averaged stats: model_time: 0.1036 (0.1427)  evaluator_time: 0.0166 (0.0348)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.891
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.842
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.910
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.740
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.910
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.866
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.931
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.910
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.959
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.855
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.933
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.924
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.885
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.943
# Epoch: [10]  [ 0/45]  eta: 0:01:10  lr: 0.000500  loss: 0.1875 (0.1875)  loss_classifier: 0.0505 (0.0505)  loss_box_reg: 0.0681 (0.0681)  loss_mask: 0.0636 (0.0636)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 1.5724  data: 0.7210  max mem: 3605
# Epoch: [10]  [10/45]  eta: 0:00:53  lr: 0.000500  loss: 0.1647 (0.1828)  loss_classifier: 0.0356 (0.0429)  loss_box_reg: 0.0533 (0.0578)  loss_mask: 0.0680 (0.0743)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0039 (0.0063)  time: 1.5344  data: 0.8059  max mem: 3605
# Epoch: [10]  [20/45]  eta: 0:00:31  lr: 0.000500  loss: 0.1454 (0.1771)  loss_classifier: 0.0346 (0.0427)  loss_box_reg: 0.0416 (0.0543)  loss_mask: 0.0680 (0.0719)  loss_objectness: 0.0007 (0.0016)  loss_rpn_box_reg: 0.0028 (0.0066)  time: 1.2482  data: 0.5489  max mem: 3605
# Epoch: [10]  [30/45]  eta: 0:00:16  lr: 0.000500  loss: 0.1454 (0.1719)  loss_classifier: 0.0349 (0.0421)  loss_box_reg: 0.0412 (0.0519)  loss_mask: 0.0646 (0.0710)  loss_objectness: 0.0007 (0.0014)  loss_rpn_box_reg: 0.0018 (0.0054)  time: 0.8830  data: 0.2072  max mem: 3605
# Epoch: [10]  [40/45]  eta: 0:00:05  lr: 0.000500  loss: 0.1585 (0.1706)  loss_classifier: 0.0390 (0.0415)  loss_box_reg: 0.0457 (0.0513)  loss_mask: 0.0672 (0.0714)  loss_objectness: 0.0010 (0.0014)  loss_rpn_box_reg: 0.0026 (0.0050)  time: 0.9010  data: 0.2300  max mem: 3605
# Epoch: [10]  [44/45]  eta: 0:00:01  lr: 0.000500  loss: 0.1410 (0.1695)  loss_classifier: 0.0374 (0.0410)  loss_box_reg: 0.0457 (0.0506)  loss_mask: 0.0672 (0.0714)  loss_objectness: 0.0010 (0.0017)  loss_rpn_box_reg: 0.0026 (0.0048)  time: 0.8951  data: 0.2223  max mem: 3605
# Epoch: [10] Total time: 0:00:47 (1.0569 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:12  model_time: 0.2498 (0.2498)  evaluator_time: 0.0576 (0.0576)  time: 0.7704  data: 0.4601  max mem: 3605
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1036 (0.1422)  evaluator_time: 0.0186 (0.0357)  time: 0.2265  data: 0.0424  max mem: 3605
# Test: Total time: 0:00:03 (0.2409 s / it)
# Averaged stats: model_time: 0.1036 (0.1422)  evaluator_time: 0.0186 (0.0357)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.907
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.858
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.928
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.753
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.925
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.883
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.946
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.909
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.959
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.934
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.751
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.926
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.885
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.946
# Epoch: [11]  [ 0/45]  eta: 0:03:18  lr: 0.000500  loss: 0.1800 (0.1800)  loss_classifier: 0.0419 (0.0419)  loss_box_reg: 0.0526 (0.0526)  loss_mask: 0.0765 (0.0765)  loss_objectness: 0.0043 (0.0043)  loss_rpn_box_reg: 0.0046 (0.0046)  time: 4.4150  data: 3.6909  max mem: 3605
# Epoch: [11]  [10/45]  eta: 0:00:43  lr: 0.000500  loss: 0.1569 (0.1692)  loss_classifier: 0.0369 (0.0394)  loss_box_reg: 0.0417 (0.0481)  loss_mask: 0.0749 (0.0747)  loss_objectness: 0.0015 (0.0020)  loss_rpn_box_reg: 0.0021 (0.0050)  time: 1.2461  data: 0.5628  max mem: 3605
# Epoch: [11]  [20/45]  eta: 0:00:26  lr: 0.000500  loss: 0.1477 (0.1601)  loss_classifier: 0.0356 (0.0391)  loss_box_reg: 0.0399 (0.0447)  loss_mask: 0.0672 (0.0710)  loss_objectness: 0.0010 (0.0016)  loss_rpn_box_reg: 0.0020 (0.0037)  time: 0.8813  data: 0.1989  max mem: 3605
# Epoch: [11]  [30/45]  eta: 0:00:16  lr: 0.000500  loss: 0.1390 (0.1645)  loss_classifier: 0.0356 (0.0403)  loss_box_reg: 0.0359 (0.0466)  loss_mask: 0.0654 (0.0713)  loss_objectness: 0.0009 (0.0015)  loss_rpn_box_reg: 0.0020 (0.0047)  time: 1.0399  data: 0.3541  max mem: 3605
# ...
# Epoch: [16]  [30/45]  eta: 0:00:14  lr: 0.000500  loss: 0.1360 (0.1506)  loss_classifier: 0.0309 (0.0343)  loss_box_reg: 0.0346 (0.0416)  loss_mask: 0.0690 (0.0697)  loss_objectness: 0.0007 (0.0014)  loss_rpn_box_reg: 0.0016 (0.0036)  time: 0.8686  data: 0.1758  max mem: 3614
# Epoch: [16]  [40/45]  eta: 0:00:04  lr: 0.000500  loss: 0.1392 (0.1492)  loss_classifier: 0.0328 (0.0345)  loss_box_reg: 0.0351 (0.0405)  loss_mask: 0.0689 (0.0694)  loss_objectness: 0.0007 (0.0016)  loss_rpn_box_reg: 0.0015 (0.0031)  time: 0.8563  data: 0.1968  max mem: 3614
# Epoch: [16]  [44/45]  eta: 0:00:00  lr: 0.000500  loss: 0.1335 (0.1480)  loss_classifier: 0.0314 (0.0341)  loss_box_reg: 0.0351 (0.0401)  loss_mask: 0.0622 (0.0691)  loss_objectness: 0.0006 (0.0016)  loss_rpn_box_reg: 0.0014 (0.0030)  time: 0.7837  data: 0.1512  max mem: 3614
# Epoch: [16] Total time: 0:00:40 (0.9057 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:12  model_time: 0.2721 (0.2721)  evaluator_time: 0.0441 (0.0441)  time: 0.7725  data: 0.4529  max mem: 3614
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1027 (0.1394)  evaluator_time: 0.0161 (0.0387)  time: 0.2287  data: 0.0453  max mem: 3614
# Test: Total time: 0:00:03 (0.2431 s / it)
# Averaged stats: model_time: 0.1027 (0.1394)  evaluator_time: 0.0161 (0.0387)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.911
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.935
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.753
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.928
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.885
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.948
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.910
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.959
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.853
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.933
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.927
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.888
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.946
# Epoch: [17]  [ 0/45]  eta: 0:01:11  lr: 0.000500  loss: 0.1374 (0.1374)  loss_classifier: 0.0291 (0.0291)  loss_box_reg: 0.0397 (0.0397)  loss_mask: 0.0653 (0.0653)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.5895  data: 0.9049  max mem: 3614
# Epoch: [17]  [10/45]  eta: 0:00:50  lr: 0.000500  loss: 0.1365 (0.1438)  loss_classifier: 0.0291 (0.0322)  loss_box_reg: 0.0397 (0.0405)  loss_mask: 0.0631 (0.0670)  loss_objectness: 0.0008 (0.0010)  loss_rpn_box_reg: 0.0014 (0.0032)  time: 1.4403  data: 0.7596  max mem: 3614
# Epoch: [17]  [20/45]  eta: 0:00:31  lr: 0.000500  loss: 0.1324 (0.1453)  loss_classifier: 0.0331 (0.0334)  loss_box_reg: 0.0370 (0.0410)  loss_mask: 0.0631 (0.0668)  loss_objectness: 0.0008 (0.0012)  loss_rpn_box_reg: 0.0020 (0.0030)  time: 1.2272  data: 0.5392  max mem: 3614
# Epoch: [17]  [30/45]  eta: 0:00:17  lr: 0.000500  loss: 0.1461 (0.1545)  loss_classifier: 0.0337 (0.0358)  loss_box_reg: 0.0382 (0.0437)  loss_mask: 0.0678 (0.0699)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0023 (0.0035)  time: 1.0279  data: 0.3311  max mem: 3614
# Epoch: [17]  [40/45]  eta: 0:00:05  lr: 0.000500  loss: 0.1450 (0.1500)  loss_classifier: 0.0314 (0.0341)  loss_box_reg: 0.0352 (0.0419)  loss_mask: 0.0676 (0.0696)  loss_objectness: 0.0008 (0.0014)  loss_rpn_box_reg: 0.0014 (0.0029)  time: 0.9980  data: 0.3313  max mem: 3614
# Epoch: [17]  [44/45]  eta: 0:00:01  lr: 0.000500  loss: 0.1353 (0.1507)  loss_classifier: 0.0305 (0.0348)  loss_box_reg: 0.0350 (0.0418)  loss_mask: 0.0667 (0.0699)  loss_objectness: 0.0006 (0.0014)  loss_rpn_box_reg: 0.0013 (0.0028)  time: 0.9230  data: 0.2764  max mem: 3614
# Epoch: [17] Total time: 0:00:48 (1.0854 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:10  model_time: 0.2289 (0.2289)  evaluator_time: 0.0434 (0.0434)  time: 0.6497  data: 0.3746  max mem: 3614
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1076 (0.1343)  evaluator_time: 0.0198 (0.0346)  time: 0.2261  data: 0.0518  max mem: 3614
# Test: Total time: 0:00:03 (0.2403 s / it)
# Averaged stats: model_time: 0.1076 (0.1343)  evaluator_time: 0.0198 (0.0346)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.908
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.855
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.935
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.927
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.880
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.948
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.908
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.959
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.853
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.933
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.749
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.923
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.883
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.943
# Epoch: [18]  [ 0/45]  eta: 0:03:17  lr: 0.000500  loss: 0.1444 (0.1444)  loss_classifier: 0.0239 (0.0239)  loss_box_reg: 0.0463 (0.0463)  loss_mask: 0.0716 (0.0716)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0021 (0.0021)  time: 4.3974  data: 3.5736  max mem: 3614
# Epoch: [18]  [10/45]  eta: 0:00:38  lr: 0.000500  loss: 0.1270 (0.1363)  loss_classifier: 0.0266 (0.0316)  loss_box_reg: 0.0317 (0.0350)  loss_mask: 0.0628 (0.0651)  loss_objectness: 0.0017 (0.0028)  loss_rpn_box_reg: 0.0016 (0.0018)  time: 1.1051  data: 0.4081  max mem: 3614
# Epoch: [18]  [20/45]  eta: 0:00:22  lr: 0.000500  loss: 0.1341 (0.1402)  loss_classifier: 0.0314 (0.0332)  loss_box_reg: 0.0319 (0.0359)  loss_mask: 0.0634 (0.0671)  loss_objectness: 0.0009 (0.0020)  loss_rpn_box_reg: 0.0018 (0.0020)  time: 0.7329  data: 0.0596  max mem: 3614
# Epoch: [18]  [30/45]  eta: 0:00:14  lr: 0.000500  loss: 0.1466 (0.1485)  loss_classifier: 0.0323 (0.0347)  loss_box_reg: 0.0383 (0.0394)  loss_mask: 0.0717 (0.0698)  loss_objectness: 0.0007 (0.0019)  loss_rpn_box_reg: 0.0019 (0.0027)  time: 0.8621  data: 0.1901  max mem: 3614
# Epoch: [18]  [40/45]  eta: 0:00:04  lr: 0.000500  loss: 0.1466 (0.1535)  loss_classifier: 0.0341 (0.0358)  loss_box_reg: 0.0397 (0.0414)  loss_mask: 0.0717 (0.0717)  loss_objectness: 0.0009 (0.0017)  loss_rpn_box_reg: 0.0017 (0.0029)  time: 1.0009  data: 0.3202  max mem: 3614
# Epoch: [18]  [44/45]  eta: 0:00:00  lr: 0.000500  loss: 0.1424 (0.1502)  loss_classifier: 0.0345 (0.0353)  loss_box_reg: 0.0369 (0.0401)  loss_mask: 0.0711 (0.0703)  loss_objectness: 0.0009 (0.0016)  loss_rpn_box_reg: 0.0017 (0.0028)  time: 0.9182  data: 0.2590  max mem: 3614
# Epoch: [18] Total time: 0:00:41 (0.9250 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:12  model_time: 0.2562 (0.2562)  evaluator_time: 0.0636 (0.0636)  time: 0.7959  data: 0.4733  max mem: 3614
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1030 (0.1436)  evaluator_time: 0.0198 (0.0351)  time: 0.2274  data: 0.0438  max mem: 3614
# Test: Total time: 0:00:03 (0.2426 s / it)
# Averaged stats: model_time: 0.1030 (0.1436)  evaluator_time: 0.0198 (0.0351)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.915
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.863
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.940
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.754
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.931
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.885
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.952
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.902
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.959
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.840
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.930
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.747
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.921
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.878
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.942
# Epoch: [19]  [ 0/45]  eta: 0:03:12  lr: 0.000500  loss: 0.1274 (0.1274)  loss_classifier: 0.0202 (0.0202)  loss_box_reg: 0.0366 (0.0366)  loss_mask: 0.0692 (0.0692)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 4.2717  data: 3.5014  max mem: 3614
# Epoch: [19]  [10/45]  eta: 0:00:38  lr: 0.000500  loss: 0.1428 (0.1452)  loss_classifier: 0.0321 (0.0318)  loss_box_reg: 0.0378 (0.0402)  loss_mask: 0.0675 (0.0682)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0017 (0.0038)  time: 1.0960  data: 0.3630  max mem: 3614
# Epoch: [19]  [20/45]  eta: 0:00:26  lr: 0.000500  loss: 0.1428 (0.1481)  loss_classifier: 0.0298 (0.0328)  loss_box_reg: 0.0378 (0.0402)  loss_mask: 0.0675 (0.0709)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0017 (0.0029)  time: 0.8893  data: 0.1629  max mem: 3614
# Epoch: [19]  [30/45]  eta: 0:00:15  lr: 0.000500  loss: 0.1296 (0.1420)  loss_classifier: 0.0291 (0.0312)  loss_box_reg: 0.0344 (0.0382)  loss_mask: 0.0664 (0.0687)  loss_objectness: 0.0007 (0.0012)  loss_rpn_box_reg: 0.0017 (0.0026)  time: 0.9575  data: 0.2509  max mem: 3614
# Epoch: [19]  [40/45]  eta: 0:00:04  lr: 0.000500  loss: 0.1268 (0.1409)  loss_classifier: 0.0291 (0.0314)  loss_box_reg: 0.0344 (0.0376)  loss_mask: 0.0639 (0.0682)  loss_objectness: 0.0005 (0.0013)  loss_rpn_box_reg: 0.0017 (0.0024)  time: 0.7975  data: 0.1275  max mem: 3614
# Epoch: [19]  [44/45]  eta: 0:00:00  lr: 0.000500  loss: 0.1225 (0.1460)  loss_classifier: 0.0293 (0.0327)  loss_box_reg: 0.0316 (0.0399)  loss_mask: 0.0614 (0.0695)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0017 (0.0027)  time: 0.8077  data: 0.1629  max mem: 3614
# Epoch: [19] Total time: 0:00:41 (0.9207 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:11  model_time: 0.2437 (0.2437)  evaluator_time: 0.0490 (0.0490)  time: 0.7464  data: 0.4508  max mem: 3614
# Test:  [15/16]  eta: 0:00:00  model_time: 0.1041 (0.1381)  evaluator_time: 0.0163 (0.0352)  time: 0.2271  data: 0.0484  max mem: 3614
# Test: Total time: 0:00:03 (0.2417 s / it)
# Averaged stats: model_time: 0.1041 (0.1381)  evaluator_time: 0.0163 (0.0352)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.907
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.856
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.932
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.926
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.880
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.947
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.908
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.959
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.852
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.932
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.747
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.925
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.890
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.944

# %%
# pick one image from the validation set
img, _ = dataset_val[10]
# put the trained model in evaluation mode
model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])

# %%
#if necessary laod the model from .bin file and put it in evaluation model
model = get_instance_segmentation_model(num_classes)
model.load_state_dict(torch.load("2_layer_trained_model_20epoch.bin"))
model = model.to(device)

# %%
import os
path = "Main/test"
images_test = [os.path.join(path, i) for i in os.listdir(path)]
dataset_test = []
trans = get_transform(train=False)
for image in images_test:
  img = Image.open(image)
  dataset_test.append(trans(img, None))

# %%
# pick one image from the test set
img, _ = dataset_test[0]
# put the model in evaluation mode
model.eval()
with torch.no_grad():
    test_p = model([img.to(device)])

# %%
cols = 8
rows = len(test_p[0]['masks']) // cols + 1
plt.figure(figsize=(14, 14 * rows // cols))

for i in range(len(test_p[0]['masks'])):
    plt.subplot(rows, cols, i+1)
    plt.axis('off')
    plt.imshow(test_p[0]['masks'][i,0].mul(255).byte().cpu().numpy())

plt.show()

# %%
# To use visualization code of matterport, Results conversion into required format
def dataManipulation(img, prediction):
  im = img.mul(255).permute(1, 2, 0).byte().numpy()
  m, _, h, w = prediction[0]['masks'].shape
  masks = np.zeros((h, w, m))
  for i in range(len(prediction[0]['masks'])):
    masks[:,:,i] = np.around(prediction[0]['masks'][i,0].data.cpu().numpy()) 
  rois = prediction[0]['boxes'].data.cpu().numpy()  
  class_names = {0: "BG", 1:"box"}
  class_ids = prediction[0]['labels'].data.cpu().numpy()

  return im, rois, masks, class_ids, class_names

# %%
import visualize

im, rois, masks, class_ids, class_names = dataManipulation(img, test_p)
visualize.display_instances(im, rois, masks, class_ids, class_names, figsize=(5,5), show_bbox=False)

# %%
cols = 8
rows = masks.shape[-1] // cols + 1
plt.figure(figsize=(14, 14 * rows // cols))

for i in range(masks.shape[-1]):
    plt.subplot(rows, cols, i+1)
    a = get_segment_crop(im, mask=masks[:,:,i])
    rgba = cv2.cvtColor(a, cv2.COLOR_RGB2RGBA)
    rgba[:, :, 3] = get_segment_crop(masks[:,:,i]*255, mask=masks[:,:,i])
    plt.axis('off')
    plt.imshow(rgba)

plt.show()

# %%
def Contour2Quadrangle(contour):
  # Approximating the contour by a quadrangle.
  # cv2.approxPolyDP is a function approximating a contour by a polygon with as few vertixes as possible 
  # under the condition that the residual of the approximation is lower than the threshold.
  # Miyazawa-San implemented a source to find appropriate threshold dynamically that let the polygon quadrangle.
  def getApprox(contour, alpha):
    epsilon = alpha * cv2.arcLength(contour, True)
    approx = cv2.approxPolyDP(contour, epsilon, True)
    return approx

  # find appropriate epsilon
  def getQuadrangle(contour):
    alpha = 0.1
    beta = 2 # larger than 1
    approx = getApprox(contour, alpha)
    if len(approx) < 4:
      while len(approx) < 4:
        alpha = alpha / beta
        approx = getApprox(contour, alpha)  
      alpha_lower = alpha
      alpha_upper = alpha * beta
    elif len(approx) > 4:
      while len(approx) > 4:
        alpha = alpha * beta
        approx = getApprox(contour, alpha)  
      alpha_lower = alpha / beta
      alpha_upper = alpha
    if len(approx) == 4:
      return approx
    alpha_middle = ( alpha_lower * alpha_upper ) ** 0.5
    approx_middle = getApprox(contour, alpha_middle)
    while len(approx_middle) != 4:
      if len(approx_middle) < 4:
        alpha_upper = alpha_middle
        approx_upper = approx_middle
      if len(approx_middle) > 4:
        alpha_lower = alpha_middle
        approx_lower = approx_middle
      alpha_middle = ( alpha_lower * alpha_upper ) ** 0.5
      approx_middle = getApprox(contour, alpha_middle)
    return approx_middle

  def getQuadrangleWithRegularOrder(contour):
    approx = getQuadrangle(contour)
    hashable_approx = [tuple(a[0]) for a in approx]
    sorted_by_axis0 = sorted(hashable_approx, key=lambda x: x[0])
    sorted_by_axis1 = sorted(hashable_approx, key=lambda x: x[1])
    topleft_set = set(sorted_by_axis0[:2]) & set(sorted_by_axis1[:2])
    #assert len(topleft_set) == 1
    if topleft_set == set():
      topleft = set(sorted_by_axis0[:2]).pop()
    else:
      topleft = topleft_set.pop()
    topleft_idx = hashable_approx.index(topleft)
    approx_with_reguler_order = [ approx[(topleft_idx + i) % 4] for i in range(4) ]
    return approx_with_reguler_order

  return getQuadrangleWithRegularOrder(contour)

# %%
rect_img_w = 600 
rect_img_h = 300 

all_plots = [im]
for i in range(masks.shape[-1]):
  contours, _ = cv2.findContours(masks[:,:,i].astype(np.uint8), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
  contour = max(contours, key=cv2.contourArea)
  corner_points = Contour2Quadrangle(contour)
  src = np.float32(list(map(lambda x: x[0], corner_points)))
  dst = np.float32([[0,0],[0, rect_img_h],[rect_img_w, rect_img_h],[rect_img_w, 0]])

  M = cv2.getPerspectiveTransform(src, dst)
  transformed = cv2.warpPerspective(im, M, (rect_img_w, rect_img_h))
  all_plots += [transformed]

visualize.display_images(all_plots, cols=8)

# %%
#Apply this fuction after prediction to remove overlapping boxes
#Haven't tried yet
def non_max_suppression(boxes, probs=None, overlapThresh=0.3):
    # if there are no boxes, return an empty list
    if len(boxes) == 0:
        return []

    # if the bounding boxes are integers, convert them to floats -- this
    # is important since we'll be doing a bunch of divisions
    if boxes.dtype.kind == "i":
        boxes = boxes.astype("float")

    # initialize the list of picked indexes
    pick = []

    # grab the coordinates of the bounding boxes
    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2]
    y2 = boxes[:, 3]

    # compute the area of the bounding boxes and grab the indexes to sort
    # (in the case that no probabilities are provided, simply sort on the
    # bottom-left y-coordinate)
    area = (x2 - x1 + 1) * (y2 - y1 + 1)
    idxs = y2

    # if probabilities are provided, sort on them instead
    if probs is not None:
        idxs = probs

    # sort the indexes
    idxs = np.argsort(idxs)

    # keep looping while some indexes still remain in the indexes list
    while len(idxs) > 0:
        # grab the last index in the indexes list and add the index value
        # to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)

        # find the largest (x, y) coordinates for the start of the bounding
        # box and the smallest (x, y) coordinates for the end of the bounding
        # box
        xx1 = np.maximum(x1[i], x1[idxs[:last]])
        yy1 = np.maximum(y1[i], y1[idxs[:last]])
        xx2 = np.minimum(x2[i], x2[idxs[:last]])
        yy2 = np.minimum(y2[i], y2[idxs[:last]])

        # compute the width and height of the bounding box
        w = np.maximum(0, xx2 - xx1 + 1)
        h = np.maximum(0, yy2 - yy1 + 1)

        # compute the ratio of overlap
        overlap = (w * h) / area[idxs[:last]]

        # delete all indexes from the index list that have overlap greater
        # than the provided overlap threshold
        idxs = np.delete(idxs, np.concatenate(([last],
            np.where(overlap > overlapThresh)[0])))

    # return only the bounding boxes that were picked
    return boxes[pick].astype("int")
